# %%
"""  :-slicing

pd.set_option('display.max_columns',85)
new_df.set_index('email',inplace=True)
new_df.reset_index(inplace=True)
schema_df.sort_index(ascending=False)

filt=df['LanguageWorkedWith'].str.contains('python',na=False)

new_df.columns=[x.upper() for x in new_df.columns]
new_df.columns=new_df.columns.str.replace('_',' ')

"""

# %%
import pandas as pd
df=pd.read_csv('survey_results_public.csv')
#df=pd.read_csv('survey_results_public.csv',index_col=Respondent)
#instead Respondent column will be considered as index

#df=pd.read_csv('survey_results_public.csv',usecols=[0,4]) reads only 4 columns
#df=pd.read_csv('survey_results_public.csv',nrows=3) reads only 3 rows

df.head(2)
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor                                           EduOther OrgSize  \
# ...

# %%
df.shape
# Out:
# (88883, 85)

# %%
#displays number of columns required
#pd.set_option('display.max_columns',2)
pd.set_option('display.max_columns',85)

# %%
schema_df=pd.read_csv('survey_results_schema.csv')
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
schema_df.shape
# Out:
# (85, 2)

# %%
pd.set_option('display.max_rows',85)

# %%
df.head(5)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df['Hobbyist'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
# df.loc[0]  #extracts 0th label persons all data
df.loc[0,'Hobbyist']
#0th row hobbyist column
# Out:
# 'Yes'

# %% [markdown]
# ## create a new data frame from a dictionery

# %%
person={
    "first":"poojitha",
    "last":"kanakamedala",
    "email":"poojithak.eee@hitam.org"
}

# %%
person={
    "first":["poojitha","suresh","madhavi"],
    "last":["kanakamedala","chappidi","pillalamarri"],
    "email":["poojithak.eee@hitam.org","sureshch.eee@hitam.org","madhavip.eee@hitam.org"]
}

# %%
person['email']
# Out:
# ['poojithak.eee@hitam.org', 'sureshch.eee@hitam.org', 'madhavip.eee@hitam.org']

# %%
#convert to data frame
import pandas as pd
new_df=pd.DataFrame(person)
new_df
# Out:
#       first          last                    email
# 0  poojitha  kanakamedala  poojithak.eee@hitam.org
# 1    suresh      chappidi   sureshch.eee@hitam.org
# 2   madhavi  pillalamarri   madhavip.eee@hitam.org

# %%
type(new_df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(new_df.email)
# Out:
# pandas.core.series.Series

# %%
new_df.count
# Out:
# <bound method DataFrame.count of       first          last                    email
# 0  poojitha  kanakamedala  poojithak.eee@hitam.org
# 1    suresh      chappidi   sureshch.eee@hitam.org
# 2   madhavi  pillalamarri   madhavip.eee@hitam.org>

# %%
s=new_df[['last','email']]
s
# Out:
#            last                    email
# 0  kanakamedala  poojithak.eee@hitam.org
# 1      chappidi   sureshch.eee@hitam.org
# 2  pillalamarri   madhavip.eee@hitam.org

# %%
type(s)

# if one column is returned then it will be of series type
#if multiple columns are returned then no more it will be series-converts to data frame as below
# Out:
# pandas.core.frame.DataFrame

# %%
#iloc-index
#loc-label
new_df.iloc[1,2]#1st row 2nd column
# Out:
# 'sureshch.eee@hitam.org'

# %%
new_df
# Out:
#       first          last                    email
# 0  poojitha  kanakamedala  poojithak.eee@hitam.org
# 1    suresh      chappidi   sureshch.eee@hitam.org
# 2   madhavi  pillalamarri   madhavip.eee@hitam.org

# %%
new_df.loc[1] #extracted with a label=0
# Out:
# first                    suresh
# last                   chappidi
# email    sureshch.eee@hitam.org
# Name: 1, dtype: object

# %%
new_df.loc[[0,1],'email']
#new_df.loc[[0,1],2]
#new_df.loc[0:1,2]
# Out:
# 0    poojithak.eee@hitam.org
# 1     sureshch.eee@hitam.org
# Name: email, dtype: object

# %%
# set email as index for new_df data frame
new_df.set_index('email')
# Out:
#                             first          last
# email
# poojithak.eee@hitam.org  poojitha  kanakamedala
# sureshch.eee@hitam.org     suresh      chappidi
# madhavip.eee@hitam.org    madhavi  pillalamarri

# %%
new_df 
#whatever changes we do in pandas the data frame will not be modified
#but if we use inplace=True df changes
# Out:
#                             first          last
# email
# poojithak.eee@hitam.org  poojitha  kanakamedala
# sureshch.eee@hitam.org     suresh      chappidi
# madhavip.eee@hitam.org    madhavi  pillalamarri

# %% [markdown]
# ## change column name

# %%
new_df
# Out:
#       first          last                    email
# 0  poojitha  kanakamedala  poojithak.eee@hitam.org
# 1    suresh      chappidi   sureshch.eee@hitam.org
# 2   madhavi  pillalamarri   madhavip.eee@hitam.org

# %%
new_df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
new_df.columns=['fist_name','last_name','email_id']
new_df
# Out:
#   fist_name     last_name                 email_id
# 0  poojitha  kanakamedala  poojithak.eee@hitam.org
# 1    suresh      chappidi   sureshch.eee@hitam.org
# 2   madhavi  pillalamarri   madhavip.eee@hitam.org

# %%
#change to upper case
new_df.columns=[x.upper() for x in new_df.columns]
new_df
# Out:
#   FIST_NAME     LAST_NAME                 EMAIL_ID
# 0  poojitha  kanakamedala  poojithak.eee@hitam.org
# 1    suresh      chappidi   sureshch.eee@hitam.org
# 2   madhavi  pillalamarri   madhavip.eee@hitam.org

# %%
#replace underscores with spaces instead
new_df.columns=new_df.columns.str.replace('_',' ')
new_df
# Out:
#   FIST NAME     LAST NAME                 EMAIL ID
# 0  poojitha  kanakamedala  poojithak.eee@hitam.org
# 1    suresh      chappidi   sureshch.eee@hitam.org
# 2   madhavi  pillalamarri   madhavip.eee@hitam.org

# %%
#change only few columns instead of all
new_df.rename(columns={'FIST NAME':'first'})
#df doesnt change as below
# Out:
#       first     LAST NAME                 EMAIL ID
# 0  poojitha  kanakamedala  poojithak.eee@hitam.org
# 1    suresh      chappidi   sureshch.eee@hitam.org
# 2   madhavi  pillalamarri   madhavip.eee@hitam.org

# %%
new_df# but if we use inplace df also changes
# Out:
#   FIST NAME     LAST NAME                 EMAIL ID
# 0  poojitha  kanakamedala  poojithak.eee@hitam.org
# 1    suresh      chappidi   sureshch.eee@hitam.org
# 2   madhavi  pillalamarri   madhavip.eee@hitam.org

# %% [markdown]
# ## change index

# %%
df=pd.read_csv('survey_results_public.csv',index_col='Respondent')
df.head(2)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %%
schema_df=pd.read_csv('survey_results_schema.csv',index_col='Column')
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
schema_df.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
schema_df.sort_index()
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %%
schema_df.sort_index(ascending=False)
# Out:
#                                                              QuestionText
# Column
# YearsCodePro            How many years have you coded professionally (...
# YearsCode               Including any education, how many years have y...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkRemote                                How often do you work remotely?
# WorkPlan                          How structured or planned is your work?
# WorkLoc                                   Where would you prefer to work?
# WorkChallenge           Of these options, what are your greatest chall...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# UnitTests               Does your company regularly employ unit tests ...
# UndergradMajor          What was your main or most important field of ...
# ...

# %% [markdown]
# ## apply filters

# %%
person={
    "first":["poojitha","suresh","madhavi"],
    "last":["kanakamedala","chappidi","pillalamarri"],
    "email":["poojithak.eee@hitam.org","sureshch.eee@hitam.org","madhavip.eee@hitam.org"]
}
import pandas as pd
new_df=pd.DataFrame(person)
new_df
# Out:
#       first          last                    email
# 0  poojitha  kanakamedala  poojithak.eee@hitam.org
# 1    suresh      chappidi   sureshch.eee@hitam.org
# 2   madhavi  pillalamarri   madhavip.eee@hitam.org

# %%
new_df['last']=='chappidi'
# Out:
# 0    False
# 1     True
# 2    False
# Name: last, dtype: bool

# %%
filt=(new_df['last']=='chappidi')

# %%
filt
# Out:
# 0    False
# 1     True
# 2    False
# Name: last, dtype: bool

# %%
new_df[filt]
# Out:
#     first      last                   email
# 1  suresh  chappidi  sureshch.eee@hitam.org

# %%
new_df.loc[filt,'email']
# Out:
# 1    sureshch.eee@hitam.org
# Name: email, dtype: object

# %%
filt1=((df.first=='suresh') & (df.last=='chappidi'))
filt1
# Out:
# False

# %%
df.head(2)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %%
df.ConvertedComp
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: ConvertedComp, Length: 88883, dtype: float64

# %%
high_salary=(df['ConvertedComp']>7000)
high_salary
# Out:
# Respondent
# 1        False
# 2        False
# 3         True
# 4         True
# 5        False
#          ...
# 88377    False
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: ConvertedComp, Length: 88883, dtype: bool

# %%
df.loc[high_salary]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 6           I am not primarily a developer, but I write co...      Yes
# 9                              I am a developer by profession      Yes
# 10                             I am a developer by profession      Yes
# ...                                                       ...      ...
# 88878                          I am a developer by profession      Yes
# 88879                          I am a developer by profession      Yes
# 88881                          I am a developer by profession      Yes
# 88882                          I am a developer by profession      Yes
# 88883                          I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 3                                Never
# ...

# %%
df.loc[high_salary,['Country','LanguageWorkedWith','ConvertedComp']]
# Out:
#                   Country                                 LanguageWorkedWith  \
# Respondent
# 3                Thailand                                           HTML/CSS
# 4           United States                                C;C++;C#;Python;SQL
# 6                  Canada                                         Java;R;SQL
# 9             New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 10                  India                      C#;Go;JavaScript;Python;R;SQL
# ...                   ...                                                ...
# 88878       United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879             Finland                   Bash/Shell/PowerShell;C++;Python
# 88881             Austria  Bash/Shell/PowerShell;Go;HTML/CSS;Java;JavaScr...
# 88882         Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
# 88883              Greece              Go;HTML/CSS;Java;JavaScript;Other(s):
#
#             ConvertedComp
# ...

# %%
filt=df['LanguageWorkedWith'].str.contains('python',na=False)

# %%
df.loc[filt,['LanguageWorkedWith','Country']]
# Out:
# Empty DataFrame
# Columns: [LanguageWorkedWith, Country]
# Index: []

# %%
df.sort_values(by=['Country', 'ConvertedComp'], ascending=[True, False], inplace=True)

# %%
df[['Country', 'ConvertedComp']].head(50)
# Out:
#                 Country  ConvertedComp
# Respondent
# 63129       Afghanistan      1000000.0
# 50499       Afghanistan       153216.0
# 39258       Afghanistan        19152.0
# 58450       Afghanistan        17556.0
# 7085        Afghanistan        14364.0
# 22450       Afghanistan         7980.0
# 48436       Afghanistan         4464.0
# 10746       Afghanistan         3996.0
# 8149        Afghanistan         1596.0
# 29736       Afghanistan         1116.0
# 722         Afghanistan            0.0
# 28638       Afghanistan            0.0
# 6417        Afghanistan            NaN
# 7353        Afghanistan            NaN
# 12310       Afghanistan            NaN
# 26340       Afghanistan            NaN
# 29045       Afghanistan            NaN
# 33178       Afghanistan            NaN
# 37802       Afghanistan            NaN
# 40000       Afghanistan            NaN
# 43106       Afghanistan            NaN
# 44403       Afghanistan            NaN
# 45854       Afghanistan            NaN
# ...

# %%
df['ConvertedComp'].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df.nlargest(10,'ConvertedComp')
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 25983                          I am a developer by profession      Yes
# 87896                          I am a developer by profession      Yes
# 22013                          I am a developer by profession      Yes
# 28243                          I am a developer by profession      Yes
# 72732       I am not primarily a developer, but I write co...       No
# 78151                          I am a developer by profession      Yes
# 80200                          I am a developer by profession      Yes
# 52132                          I am a developer by profession      Yes
# 75561                          I am a developer by profession      Yes
# 32250                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 25983                                 Less than once per year
# ...

# %%
df['ConvertedComp'].nsmallest(10)
# Out:
# Respondent
# 722      0.0
# 28638    0.0
# 13825    0.0
# 40913    0.0
# 30630    0.0
# 69049    0.0
# 19340    0.0
# 16214    0.0
# 29355    0.0
# 1685     0.0
# Name: ConvertedComp, dtype: float64
